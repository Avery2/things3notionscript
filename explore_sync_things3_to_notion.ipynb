# %%
import things
from dotenv import load_dotenv
from notion_client import Client
import os
from typing import Union, TypedDict, Optional

# %%
# things.projects()

# %%
len(things.tasks())
# {'uuid': 'Ckm2B2GYLrZ179b3aSqXF8',
#  'type': 'to-do',
#  'title': 'ivan',
#  'status': 'incomplete',
#  'project': 'UuJfnrXq2yxnCCKQzBYX2r',
#  'project_title': 'people',
#  'notes': '',
#  'start': 'Anytime',
#  'start_date': None,
#  'deadline': None,
#  'stop_date': None,
#  'created': '2022-07-17 09:34:49',
#  'modified': '2022-07-20 16:37:08',
#  'index': -137026,
#  'today_index': 0}
# Out:
# 174

# %%
# This is how to get all tasks
things.tasks()[0] # gets first of all tasks
# Out:
# {'uuid': 'Ckm2B2GYLrZ179b3aSqXF8',
#  'type': 'to-do',
#  'title': 'ivan',
#  'status': 'incomplete',
#  'project': 'UuJfnrXq2yxnCCKQzBYX2r',
#  'project_title': 'people',
#  'notes': '',
#  'start': 'Anytime',
#  'start_date': None,
#  'deadline': None,
#  'stop_date': None,
#  'created': '2022-07-17 09:34:49',
#  'modified': '2022-07-20 16:37:08',
#  'index': -137026,
#  'today_index': 0}

# %%
all_tasks = [t for t in things.tasks(status=None)]
len(all_tasks)
# Out:
# 7542

# %%
# set([t['status'] for t in things.tasks()])
# status : {'incomplete', 'completed', 'canceled'}

# %%
# [t['type'] for t in things.tasks() if t['type'] != 'to-do']

# %%
load_dotenv()
my_key = os.getenv("DB_ID")
my_token = os.getenv("NOTION_TOKEN")
notion = Client(auth=my_token)
page_id = "28d4c7f1-aca1-4a14-bf3e-4ea87d693287"

# %%
len(all_tasks)
# Out:
# 7542

# %%
# for each task in all_tasks I want to sync it to the Notion DB: https://www.notion.so/avery2/a1fd716f1a6b4ae6b5fcd8e6817f9af3?v=97a4eddd003f4c6cb9b7d6e0961bdfd2
notion_db_url = "https://www.notion.so/avery2/a1fd716f1a6b4ae6b5fcd8e6817f9af3?v=97a4eddd003f4c6cb9b7d6e0961bdfd2"
notion_db_id = "a1fd716f1a6b4ae6b5fcd8e6817f9af3"

# %% [markdown]
#  From the docs auto generated code:

# %%
# import requests

# url = "https://api.notion.com/v1/pages/a1fd716f1a6b4ae6b5fcd8e6817f9af3"

# headers = {
#     "accept": "application/json",
#     "Notion-Version": "2022-06-28",
#     "authorization": "Bearer secret_WtaDbd5hEzeF8A4eppjHHCfJsuuK4gEqITpu0ikcXgM"
# }

# response = requests.get(url, headers=headers)

# print(response.text)

# %% [markdown]
# Using notion python library:

# %%
# get properties
notion_properties = notion.databases.retrieve(notion_db_id)['properties']
notion_properties
# Out:
# {'status': {'id': 'PBVs',
#   'name': 'status',
#   'type': 'checkbox',
#   'checkbox': {}},
#  'deleted': {'id': 'ouMw',
#   'name': 'deleted',
#   'type': 'checkbox',
#   'checkbox': {}},
#  'uuid': {'id': 'wrMk', 'name': 'uuid', 'type': 'rich_text', 'rich_text': {}},
#  'title': {'id': 'title', 'name': 'title', 'type': 'title', 'title': {}}}

# %%
# get existing pages as python objects

query = notion.databases.query(notion_db_id)
notin_db_pages = query['results']
print(len(notin_db_pages))
# notin_db_pages[0]
notin_db_pages
# Out:
# 100
# [{'object': 'page',
#   'id': '6eb05a24-24c5-4c42-8101-b6ded183d5b4',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'P9CmicrK2KLEuKQv1QEtFw', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'P9CmicrK2KLEuKQv1QEtFw',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'enforce https on all github pages stuff',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'enforce https on all github pages stuff',
#       'href': None}]}},
#   'url': 'https://www.notion.so/enforce-https-on-all-github-pages-stuff-6eb05a2424c54c428101b6ded183d5b4'},
#  {'object': 'page',
#   'id': '25c99d33-ab45-41b3-b717-f9288d05c55d',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '5TN8U5fDdnYN1HWDmGaEFQ', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '5TN8U5fDdnYN1HWDmGaEFQ',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'ask tambre about rent', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'ask tambre about rent',
#       'href': None}]}},
#   'url': 'https://www.notion.so/ask-tambre-about-rent-25c99d33ab4541b3b717f9288d05c55d'},
#  {'object': 'page',
#   'id': 'e0b91193-8cce-4a55-8d4f-4234303845c2',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '4NprSZ4VspE8vLfp6bvHH8', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '4NprSZ4VspE8vLfp6bvHH8',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'get a suit and stuff', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'get a suit and stuff',
#       'href': None}]}},
#   'url': 'https://www.notion.so/get-a-suit-and-stuff-e0b911938cce4a558d4f4234303845c2'},
#  {'object': 'page',
#   'id': '9fb99345-4953-481a-8a92-49dc9b4c5a3f',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '28kGp1WgWwk41rw4XRLrUy', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '28kGp1WgWwk41rw4XRLrUy',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'big brother poster', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'big brother poster',
#       'href': None}]}},
#   'url': 'https://www.notion.so/big-brother-poster-9fb993454953481a8a9249dc9b4c5a3f'},
#  {'object': 'page',
#   'id': '4502fabb-3f09-4595-ad02-2de0f0c7e46e',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'A4TZexUegKMWofUQpXPkLN', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'A4TZexUegKMWofUQpXPkLN',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'start recruiting', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'start recruiting',
#       'href': None}]}},
#   'url': 'https://www.notion.so/start-recruiting-4502fabb3f094595ad022de0f0c7e46e'},
#  {'object': 'page',
#   'id': '0c942863-23c6-4726-a248-c3d2da19e99a',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '5TgpP7U7CufVkkUguSeuvo', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '5TgpP7U7CufVkkUguSeuvo',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'bring water to alcatraz', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'bring water to alcatraz',
#       'href': None}]}},
#   'url': 'https://www.notion.so/bring-water-to-alcatraz-0c94286323c64726a248c3d2da19e99a'},
#  {'object': 'page',
#   'id': '75254098-4873-4aee-9610-7d8d7a47bcf6',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '8Wy8a4q3vxVdjaFwsmmJ3D', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '8Wy8a4q3vxVdjaFwsmmJ3D',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'cups and plates', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'cups and plates',
#       'href': None}]}},
#   'url': 'https://www.notion.so/cups-and-plates-7525409848734aee96107d8d7a47bcf6'},
#  {'object': 'page',
#   'id': 'c2072d55-2631-42b5-95ff-805f9a364b83',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'XMZ99hRrzLf2UYJojAqa3Z', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'XMZ99hRrzLf2UYJojAqa3Z',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'show your work! book short', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'show your work! book short',
#       'href': None}]}},
#   'url': 'https://www.notion.so/show-your-work-book-short-c2072d55263142b595ff805f9a364b83'},
#  {'object': 'page',
#   'id': 'c309ea9c-18e2-478f-8265-987e6c890995',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'VwFxCmYQ8xrtFpezYD87nb', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'VwFxCmYQ8xrtFpezYD87nb',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'send text of video to roro', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'send text of video to roro',
#       'href': None}]}},
#   'url': 'https://www.notion.so/send-text-of-video-to-roro-c309ea9c18e2478f8265987e6c890995'},
#  {'object': 'page',
#   'id': 'b73a02b7-8e97-4c19-bff9-6ce7796aa457',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '3b4PS8knf9nsNCvRJQL9st', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '3b4PS8knf9nsNCvRJQL9st',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'long term I might want to get comfortable with Javascript and Java because that seems what tools are there — the same joy that I can get from Python it’d be cool if I could get from those two.',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'long term I might want to get comfortable with Javascript and Java because that seems what tools are there — the same joy that I can get from Python it’d be cool if I could get from those two.',
#       'href': None}]}},
#   'url': 'https://www.notion.so/long-term-I-might-want-to-get-comfortable-with-Javascript-and-Java-because-that-seems-what-tools-are-b73a02b78e974c19bff96ce7796aa457'},
#  {'object': 'page',
#   'id': '83e5d97b-310b-4340-bf6c-f664e4b1319a',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'SADnakJNWQUB6mdc1EgSJh', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'SADnakJNWQUB6mdc1EgSJh',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'replace $20', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'replace $20',
#       'href': None}]}},
#   'url': 'https://www.notion.so/replace-20-83e5d97b310b4340bf6cf664e4b1319a'},
#  {'object': 'page',
#   'id': '6a3dff75-ef02-4720-adc6-e629fa4e4bc4',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'QweDZQ3ogK7udof7sNAWtV', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'QweDZQ3ogK7udof7sNAWtV',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'ask tambre if i can change password back',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'ask tambre if i can change password back',
#       'href': None}]}},
#   'url': 'https://www.notion.so/ask-tambre-if-i-can-change-password-back-6a3dff75ef024720adc6e629fa4e4bc4'},
#  {'object': 'page',
#   'id': 'd8e9d509-84fc-441d-a2c6-594345f428a0',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'NoNnmUb44vbUp4zpR6nzEx', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'NoNnmUb44vbUp4zpR6nzEx',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'send tambre party text', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'send tambre party text',
#       'href': None}]}},
#   'url': 'https://www.notion.so/send-tambre-party-text-d8e9d50984fc441da2c6594345f428a0'},
#  {'object': 'page',
#   'id': '1a51d889-1950-47e2-a90c-af0aec95a610',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'DBfLpjydKwpf45G4CkZWze', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'DBfLpjydKwpf45G4CkZWze',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '“fun” replacement: 1hr research 2h code',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '“fun” replacement: 1hr research 2h code',
#       'href': None}]}},
#   'url': 'https://www.notion.so/fun-replacement-1hr-research-2h-code-1a51d889195047e2a90caf0aec95a610'},
#  {'object': 'page',
#   'id': '3f16e156-6133-4e86-b584-75cb1fb0f574',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'Qheoy2v1TBrH6icNoZqXXs', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Qheoy2v1TBrH6icNoZqXXs',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'meetings with advisors 3 year plan', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'meetings with advisors 3 year plan',
#       'href': None}]}},
#   'url': 'https://www.notion.so/meetings-with-advisors-3-year-plan-3f16e15661334e86b58475cb1fb0f574'},
#  {'object': 'page',
#   'id': '4bd0d6a9-faa1-490b-a5a6-1463288fb6f7',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '7Pmife2MZGH3B1mAHLWsV5', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '7Pmife2MZGH3B1mAHLWsV5',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'https://github.com/amplitude/javascript/pull/18182',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'https://github.com/amplitude/javascript/pull/18182',
#       'href': None}]}},
#   'url': 'https://www.notion.so/https-github-com-amplitude-javascript-pull-18182-4bd0d6a9faa1490ba5a61463288fb6f7'},
#  {'object': 'page',
#   'id': '35db67be-7112-4b66-a83e-012a1f047768',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'VMFRcrEPn51VFAvpe7iNQ2', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'VMFRcrEPn51VFAvpe7iNQ2',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '[] clean up profiles', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '[] clean up profiles',
#       'href': None}]}},
#   'url': 'https://www.notion.so/clean-up-profiles-35db67be71124b66a83e012a1f047768'},
#  {'object': 'page',
#   'id': '4bc8de36-5987-4b92-a588-392c508a7faa',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'LfkkdD9qHQZ4wiSWZ9k7e', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'LfkkdD9qHQZ4wiSWZ9k7e',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': "download more photos to phone to see if it'll choose more poeple",
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': "download more photos to phone to see if it'll choose more poeple",
#       'href': None}]}},
#   'url': 'https://www.notion.so/download-more-photos-to-phone-to-see-if-it-ll-choose-more-poeple-4bc8de3659874b92a588392c508a7faa'},
#  {'object': 'page',
#   'id': '3e8cdb82-1246-4b3f-9203-1c1acaa0770a',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '48XgrGPrV5C1bg2dNG7md6', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '48XgrGPrV5C1bg2dNG7md6',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'superintelligence read', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'superintelligence read',
#       'href': None}]}},
#   'url': 'https://www.notion.so/superintelligence-read-3e8cdb8212464b3f92031c1acaa0770a'},
#  {'object': 'page',
#   'id': 'c5a9e09d-4a62-4627-9bf2-6be74ac30264',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'GrtpbEhDGnSk3pMmZJKLdb', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'GrtpbEhDGnSk3pMmZJKLdb',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'check in flight; and other emails', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'check in flight; and other emails',
#       'href': None}]}},
#   'url': 'https://www.notion.so/check-in-flight-and-other-emails-c5a9e09d4a6246279bf26be74ac30264'},
#  {'object': 'page',
#   'id': 'cce8b4f2-10e2-4608-a7cf-8ece3cab18d3',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '38paQujTUCLxqoRvLwsewG', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '38paQujTUCLxqoRvLwsewG',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'ask tambre palo alto -- palo alto networks about referral ',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'ask tambre palo alto -- palo alto networks about referral ',
#       'href': None}]}},
#   'url': 'https://www.notion.so/ask-tambre-palo-alto-palo-alto-networks-about-referral-cce8b4f210e24608a7cf8ece3cab18d3'},
#  {'object': 'page',
#   'id': '59ae294b-c4bb-4b65-9404-dbd095c66c22',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'KXxk3YWtsrfHAGGztqkSqX', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'KXxk3YWtsrfHAGGztqkSqX',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'extremely loud and increasingly close',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'extremely loud and increasingly close',
#       'href': None}]}},
#   'url': 'https://www.notion.so/extremely-loud-and-increasingly-close-59ae294bc4bb4b659404dbd095c66c22'},
#  {'object': 'page',
#   'id': '0775f337-329f-4015-84b7-b21f616ace29',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'QhAeFDhJ2M9LEysgCgY19B', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'QhAeFDhJ2M9LEysgCgY19B',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'cut nails', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'cut nails',
#       'href': None}]}},
#   'url': 'https://www.notion.so/cut-nails-0775f337329f401584b7b21f616ace29'},
#  {'object': 'page',
#   'id': 'a5bd4a00-b98f-4cb8-ad8c-84b8b2e5da91',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'A5jwEjWAfshuT4rGwj9KE7', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'A5jwEjWAfshuT4rGwj9KE7',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'octo bio hear back?', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'octo bio hear back?',
#       'href': None}]}},
#   'url': 'https://www.notion.so/octo-bio-hear-back-a5bd4a00b98f4cb8ad8c84b8b2e5da91'},
#  {'object': 'page',
#   'id': 'd67dd961-5c29-481e-9c0a-20107fd9f3db',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'QKBWHUYjVqF5Ec3YxABSPi', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'QKBWHUYjVqF5Ec3YxABSPi',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'CS 567- Medical Image Analysis', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'CS 567- Medical Image Analysis',
#       'href': None}]}},
#   'url': 'https://www.notion.so/CS-567-Medical-Image-Analysis-d67dd9615c29481e9c0a20107fd9f3db'},
#  {'object': 'page',
#   'id': '8f7b9024-e4fe-4547-9b3c-ac828dd59150',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'P366jNVkDeT4HdUWR8B96v', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'P366jNVkDeT4HdUWR8B96v',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'make sure sam gets her money', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'make sure sam gets her money',
#       'href': None}]}},
#   'url': 'https://www.notion.so/make-sure-sam-gets-her-money-8f7b9024e4fe45479b3cac828dd59150'},
#  {'object': 'page',
#   'id': '9073efef-22e1-45d1-a977-7b99fd5ee32c',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'MRCKCxT54CzuX9PeAVm7Ft', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'MRCKCxT54CzuX9PeAVm7Ft',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'EA app', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'EA app',
#       'href': None}]}},
#   'url': 'https://www.notion.so/EA-app-9073efef22e145d1a9777b99fd5ee32c'},
#  {'object': 'page',
#   'id': '3f6d5bd6-4f7f-45c1-88bf-cc2ce88c569d',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '4oTwAVcyih1dnsFJgHpdnz', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '4oTwAVcyih1dnsFJgHpdnz',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'debug idea; also ask questions bc this is unproductive',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'debug idea; also ask questions bc this is unproductive',
#       'href': None}]}},
#   'url': 'https://www.notion.so/debug-idea-also-ask-questions-bc-this-is-unproductive-3f6d5bd64f7f45c188bfcc2ce88c569d'},
#  {'object': 'page',
#   'id': '31dbb98d-55f5-43a6-ac58-aff9454c097f',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '4qpeAXHof2xiryjCKGVxYU', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '4qpeAXHof2xiryjCKGVxYU',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'johnson ML clubs (computer vision n shit)',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'johnson ML clubs (computer vision n shit)',
#       'href': None}]}},
#   'url': 'https://www.notion.so/johnson-ML-clubs-computer-vision-n-shit-31dbb98d55f543a6ac58aff9454c097f'},
#  {'object': 'page',
#   'id': 'd8b440be-f8c0-4d4c-b7d8-21d4b8a8b33e',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '2LTaSHMttBNLTGNKZdqjMa', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2LTaSHMttBNLTGNKZdqjMa',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'make sure angie gets her money', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'make sure angie gets her money',
#       'href': None}]}},
#   'url': 'https://www.notion.so/make-sure-angie-gets-her-money-d8b440bef8c04d4cb7d821d4b8a8b33e'},
#  {'object': 'page',
#   'id': '9fa02e09-bd53-498e-8849-620cf7fae0c5',
#   'created_time': '2022-11-05T22:45:00.000Z',
#   'last_edited_time': '2022-11-05T22:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'MysA3n98pLavoqETreahQr', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'MysA3n98pLavoqETreahQr',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'quote', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'quote',
#       'href': None}]}},
#   'url': 'https://www.notion.so/quote-9fa02e09bd53498e8849620cf7fae0c5'},
#  {'object': 'page',
# ...
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Hdc9fVFY5SrG914s6n7ENy',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Medical info: follow up with HR', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Medical info: follow up with HR',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Medical-info-follow-up-with-HR-6cfde5c59738424e930458753dde6866'},
#  {'object': 'page',
#   'id': '7fbd8cb9-5471-43a6-8535-3a408868c79b',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'CPDQsWQuSPasY2DxYzzfX8', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'CPDQsWQuSPasY2DxYzzfX8',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'to angie $10 snacks', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'to angie $10 snacks',
#       'href': None}]}},
#   'url': 'https://www.notion.so/to-angie-10-snacks-7fbd8cb9547143a685353a408868c79b'},
#  {'object': 'page',
#   'id': '86dda42a-1f9c-4a9c-acc1-e4fe67a92bfe',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '3gHyyaSDufVzWv3jwEi2ne', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '3gHyyaSDufVzWv3jwEi2ne',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Look through medical; connect; get insurance; get checkups',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Look through medical; connect; get insurance; get checkups',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Look-through-medical-connect-get-insurance-get-checkups-86dda42a1f9c4a9cacc1e4fe67a92bfe'},
#  {'object': 'page',
#   'id': '25f5441e-5d88-41df-abb3-0a1d3ee9f524',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'RS34gCXXemDxf6zqL6tKVv', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'RS34gCXXemDxf6zqL6tKVv',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'https://youtu.be/EDFQaPyliIw', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'https://youtu.be/EDFQaPyliIw',
#       'href': None}]}},
#   'url': 'https://www.notion.so/https-youtu-be-EDFQaPyliIw-25f5441e5d8841dfabb30a1d3ee9f524'},
#  {'object': 'page',
#   'id': 'd0638759-203a-453a-96c6-d8e0d6e96021',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '2pDEnFZQzE6XS54D3WJg1k', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2pDEnFZQzE6XS54D3WJg1k',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'update sleep shortcut iphone', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'update sleep shortcut iphone',
#       'href': None}]}},
#   'url': 'https://www.notion.so/update-sleep-shortcut-iphone-d0638759203a453a96c6d8e0d6e96021'},
#  {'object': 'page',
#   'id': 'f62475db-ed3f-4f9a-8ed0-f6683d2827cd',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '9Yb23DfgauigZwFHicX9jG', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '9Yb23DfgauigZwFHicX9jG',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'triangle', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'triangle',
#       'href': None}]}},
#   'url': 'https://www.notion.so/triangle-f62475dbed3f4f9a8ed0f6683d2827cd'},
#  {'object': 'page',
#   'id': '80bc6bef-ea7d-436a-b8ea-111abacf34a2',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'HrPTs3WXNRyHGybRBQkEw5', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'HrPTs3WXNRyHGybRBQkEw5',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'pay chris wine', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'pay chris wine',
#       'href': None}]}},
#   'url': 'https://www.notion.so/pay-chris-wine-80bc6befea7d436ab8ea111abacf34a2'},
#  {'object': 'page',
#   'id': '8a5052be-ce08-4a15-ae0e-9b46a613349e',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': False},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'CJcraTWsKLUtFuWuV1gQja', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'CJcraTWsKLUtFuWuV1gQja',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'meta more often', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'meta more often',
#       'href': None}]}},
#   'url': 'https://www.notion.so/meta-more-often-8a5052bece084a15ae0e9b46a613349e'},
#  {'object': 'page',
#   'id': 'adcc502c-0443-4346-98fc-449e5c2e89dd',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'Fcv4RwzafxbEf8btk5HzZs', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Fcv4RwzafxbEf8btk5HzZs',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'add office hours to google cal -> plan to go?',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'add office hours to google cal -> plan to go?',
#       'href': None}]}},
#   'url': 'https://www.notion.so/add-office-hours-to-google-cal-plan-to-go-adcc502c0443434698fc449e5c2e89dd'},
#  {'object': 'page',
#   'id': 'e900407c-e608-4dc1-8ebe-f557e494bfcb',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'B139iYAV2c9asRKjQ82fsL', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'B139iYAV2c9asRKjQ82fsL',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'type 1 type 2 thoughts angie?', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'type 1 type 2 thoughts angie?',
#       'href': None}]}},
#   'url': 'https://www.notion.so/type-1-type-2-thoughts-angie-e900407ce6084dc18ebef557e494bfcb'},
#  {'object': 'page',
#   'id': '3d056108-58dc-4c4a-8a0a-1b4345100c91',
#   'created_time': '2022-11-05T22:44:00.000Z',
#   'last_edited_time': '2022-11-05T22:44:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'last_edited_by': {'object': 'user',
#    'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#   'archived': False,
#   'properties': {'status': {'id': 'PBVs',
#     'type': 'checkbox',
#     'checkbox': True},
#    'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#    'uuid': {'id': 'wrMk',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'SC1c7QVtTtFeEHWoyTNGvy', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'SC1c7QVtTtFeEHWoyTNGvy',
#       'href': None}]},
#    'title': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Clean systems', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Clean systems',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Clean-systems-3d05610858dc4c4a8a0a1b4345100c91'}]

# %%
# notion_properties['deleted']['id']

# %%
# update property in Notion DB

property = 'deleted'
value_property = True
notion_page_id = notin_db_pages[0]['id']
notion_property_id = notion_properties[property]['id']

# properties = {notion_property_id: True}

# notion.pages.update(notion_page_id, properties=properties)

def updateNotionPage(page_id: str, property_id: str, value: Union[bool, str]):
    properties = {property_id: value}
    resonse = notion.pages.update(page_id, properties=properties)
    return resonse

updateNotionPage(notion_page_id, notion_property_id, value_property)
# Out:
# {'object': 'page',
#  'id': '643e23df-bf6c-493b-927b-e5a2d2273f0d',
#  'created_time': '2022-11-05T22:14:00.000Z',
#  'last_edited_time': '2022-11-05T22:15:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#  'last_edited_by': {'object': 'user',
#   'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#  'archived': False,
#  'properties': {'status': {'id': 'PBVs', 'type': 'checkbox', 'checkbox': True},
#   'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': True},
#   'uuid': {'id': 'wrMk',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': 'Y8hEvxoQKWq8abBHtMiuTy', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Y8hEvxoQKWq8abBHtMiuTy',
#      'href': None}]},
#   'title': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': 'refill $20', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'refill $20',
#      'href': None}]}},
#  'url': 'https://www.notion.so/refill-20-643e23dfbf6c493b927be5a2d2273f0d'}

# %%
# [p['id'] for p in notion_properties]
notion_properties
# Out:
# {'status': {'id': 'PBVs',
#   'name': 'status',
#   'type': 'checkbox',
#   'checkbox': {}},
#  'deleted': {'id': 'ouMw',
#   'name': 'deleted',
#   'type': 'checkbox',
#   'checkbox': {}},
#  'uuid': {'id': 'wrMk', 'name': 'uuid', 'type': 'rich_text', 'rich_text': {}},
#  'title': {'id': 'title', 'name': 'title', 'type': 'title', 'title': {}}}

# %%
all_tasks[0]
# Out:
# {'uuid': 'Y8hEvxoQKWq8abBHtMiuTy',
#  'type': 'to-do',
#  'title': 'refill $20',
#  'status': 'completed',
#  'notes': '',
#  'start': 'Anytime',
#  'start_date': '2022-05-27',
#  'deadline': None,
#  'stop_date': '2022-05-28',
#  'created': '2022-05-27 18:09:01',
#  'modified': '2022-05-28 21:36:33',
#  'index': -281384,
#  'today_index': 4880908}

# %%
# task = all_tasks[0]
# task['title']
# notion_properties['title']['id']

# %%
# add property to notion DB

# notion_properties_mapping = {
#     'status': None,
#     'deleted': None,
#     'uuid': None,
#     'title': None,
# }

# ! notion_properties is dependent on the shape of your Notion DB and I manaully changed it

# task = all_tasks[0]

# properties = {
#     notion_properties['title']['id']: {
#         notion_properties['title']['id']: [
#             {
#                 "text": {
#                     "content": task['title']
#                 }
#             }
#         ]
#     },
#     notion_properties['status']['id']: {
#         'checkbox': task['status'] in ('completed')
#     },
#     notion_properties['deleted']['id']: {
#         'checkbox': False, # it's not deleted if I am adding it
#     },
#     notion_properties['uuid']['id']: {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                 "content": task['uuid']
#                 }
#             },
#         ]
#     },
# }

# parent = {'database_id': notion_db_id}

# notion.pages.create(parent=parent, properties=properties)

class MyNotionDBPage(TypedDict):
    status: bool
    deleted: Optional[bool]
    uuid: str
    title: str

def addNotionPage(notion_db_id:str, page_properties: MyNotionDBPage):
    properties = {
        notion_properties['title']['id']: {
            notion_properties['title']['id']: [
                {
                    "text": {
                        "content": page_properties['title']
                    }
                }
            ]
        },
        notion_properties['status']['id']: {
            'checkbox': page_properties['status'] in ('completed')
        },
        notion_properties['deleted']['id']: {
            'checkbox': False, # it's not deleted if I am adding it
        },
        notion_properties['uuid']['id']: {
            "rich_text": [
                {
                    "type": "text",
                    "text": {
                    "content": page_properties['uuid']
                    }
                },
            ]
        },
    }
    parent = {'database_id': notion_db_id}
    return notion.pages.create(parent=parent, properties=properties)

task = all_tasks[0]
addNotionPage(notion_db_id, {
    'status': task['status'],
    'uuid': task['uuid'],
    'title': task['title'],
})
# Out:
# {'object': 'page',
#  'id': 'aafc0e1e-07ae-4377-8eef-1496c2d70804',
#  'created_time': '2022-11-05T22:15:00.000Z',
#  'last_edited_time': '2022-11-05T22:15:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#  'last_edited_by': {'object': 'user',
#   'id': '00767880-1288-4faa-9e31-2ca3731b70c1'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'a1fd716f-1a6b-4ae6-b5fc-d8e6817f9af3'},
#  'archived': False,
#  'properties': {'status': {'id': 'PBVs', 'type': 'checkbox', 'checkbox': True},
#   'deleted': {'id': 'ouMw', 'type': 'checkbox', 'checkbox': False},
#   'uuid': {'id': 'wrMk',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': 'Y8hEvxoQKWq8abBHtMiuTy', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'Y8hEvxoQKWq8abBHtMiuTy',
#      'href': None}]},
#   'title': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': 'refill $20', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'refill $20',
#      'href': None}]}},
#  'url': 'https://www.notion.so/refill-20-aafc0e1e07ae43778eef1496c2d70804'}
